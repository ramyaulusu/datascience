# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\uramy\anaconda3\lib\site-packages (2.14.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\uramy\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\uramy\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\uramy\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\uramy\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\uramy\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\uramy\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\uramy\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uramy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uramy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uramy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\uramy\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uramy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uramy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uramy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uramy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\uramy\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\uramy\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\uramy\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv(r'C:\Users\uramy\Downloads\Task_1_Stocks_dataset (3).csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 73ms/step - loss: 0.0092 - mean_absolute_error: 0.0680 - val_loss: 0.0135 - val_mean_absolute_error: 0.0995
# Epoch 2/100
# 28/28 [==============================] - 1s 45ms/step - loss: 9.1508e-04 - mean_absolute_error: 0.0244 - val_loss: 0.0019 - val_mean_absolute_error: 0.0335
# Epoch 3/100
# 28/28 [==============================] - 1s 44ms/step - loss: 4.6089e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296
# Epoch 4/100
# 28/28 [==============================] - 1s 45ms/step - loss: 4.4099e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 5/100
# 28/28 [==============================] - 1s 44ms/step - loss: 4.1877e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0023 - val_mean_absolute_error: 0.0371
# Epoch 6/100
# 28/28 [==============================] - 1s 39ms/step - loss: 4.3006e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0020 - val_mean_absolute_error: 0.0343
# Epoch 7/100
# 28/28 [==============================] - 1s 40ms/step - loss: 3.9566e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0021 - val_mean_absolute_error: 0.0354
# Epoch 8/100
# 28/28 [==============================] - 1s 41ms/step - loss: 4.2608e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0020 - val_mean_absolute_error: 0.0339
# Epoch 9/100
# 28/28 [==============================] - 1s 40ms/step - loss: 4.0690e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0021 - val_mean_absolute_error: 0.0348
# Epoch 10/100
# 28/28 [==============================] - 1s 42ms/step - loss: 3.8639e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0021 - val_mean_absolute_error: 0.0347
# Epoch 11/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.7421e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0394
# Epoch 12/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.5954e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 13/100
# 28/28 [==============================] - 1s 47ms/step - loss: 3.4447e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0024 - val_mean_absolute_error: 0.0369
# Epoch 14/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.4345e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0038 - val_mean_absolute_error: 0.0496
# Epoch 15/100
# 28/28 [==============================] - 1s 46ms/step - loss: 3.4521e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0055 - val_mean_absolute_error: 0.0616
# Epoch 16/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.7476e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382
# Epoch 17/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.3455e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411
# Epoch 18/100
# 28/28 [==============================] - 1s 49ms/step - loss: 3.3729e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0022 - val_mean_absolute_error: 0.0353
# Epoch 19/100
# 28/28 [==============================] - 1s 52ms/step - loss: 3.4325e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0034 - val_mean_absolute_error: 0.0460
# Epoch 20/100
# 28/28 [==============================] - 1s 49ms/step - loss: 3.1884e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0060 - val_mean_absolute_error: 0.0650
# Epoch 21/100
# 28/28 [==============================] - 1s 46ms/step - loss: 3.2762e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0037 - val_mean_absolute_error: 0.0493
# Epoch 22/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.4935e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0060 - val_mean_absolute_error: 0.0650
# Epoch 23/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.0109e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 24/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.7566e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0039 - val_mean_absolute_error: 0.0508
# Epoch 25/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.8048e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0036 - val_mean_absolute_error: 0.0483
# Epoch 26/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.9057e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0035 - val_mean_absolute_error: 0.0485
# Epoch 27/100
# 28/28 [==============================] - 1s 44ms/step - loss: 2.5713e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0031 - val_mean_absolute_error: 0.0444
# Epoch 28/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.6588e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0023 - val_mean_absolute_error: 0.0374
# Epoch 29/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.5290e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0042 - val_mean_absolute_error: 0.0540
# Epoch 30/100
# 28/28 [==============================] - 1s 48ms/step - loss: 2.6440e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0023 - val_mean_absolute_error: 0.0375
# Epoch 31/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.5763e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
# Epoch 32/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.4255e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0023 - val_mean_absolute_error: 0.0375
# Epoch 33/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.5213e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0015 - val_mean_absolute_error: 0.0289
# Epoch 34/100
# 28/28 [==============================] - 1s 44ms/step - loss: 2.5769e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0022 - val_mean_absolute_error: 0.0366
# Epoch 35/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.3828e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0034 - val_mean_absolute_error: 0.0475
# Epoch 36/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.4949e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0032 - val_mean_absolute_error: 0.0454
# Epoch 37/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.3345e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0024 - val_mean_absolute_error: 0.0389
# Epoch 38/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.4492e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0032 - val_mean_absolute_error: 0.0472
# Epoch 39/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.2550e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0036 - val_mean_absolute_error: 0.0493
# Epoch 40/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.3642e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0029 - val_mean_absolute_error: 0.0434
# Epoch 41/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.2676e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0031 - val_mean_absolute_error: 0.0447
# Epoch 42/100
# 28/28 [==============================] - 1s 44ms/step - loss: 2.1337e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0020 - val_mean_absolute_error: 0.0348
# Epoch 43/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.1376e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 44/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.5421e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0020 - val_mean_absolute_error: 0.0344
# Epoch 45/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.0349e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 46/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.1063e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0024 - val_mean_absolute_error: 0.0386
# Epoch 47/100
# 28/28 [==============================] - 1s 43ms/step - loss: 2.1820e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0019 - val_mean_absolute_error: 0.0341
# Epoch 48/100
# 28/28 [==============================] - 1s 44ms/step - loss: 2.0908e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0031 - val_mean_absolute_error: 0.0449
# Epoch 49/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.2916e-04 - mean_absolute_error: 0.0112 - val_loss: 9.9306e-04 - val_mean_absolute_error: 0.0231
# Epoch 50/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.2688e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367
# Epoch 51/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.9715e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0026 - val_mean_absolute_error: 0.0423
# Epoch 52/100
# 28/28 [==============================] - 1s 44ms/step - loss: 2.0578e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0023 - val_mean_absolute_error: 0.0388
# Epoch 53/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.9912e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356
# Epoch 54/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.8732e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0030 - val_mean_absolute_error: 0.0459
# Epoch 55/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.8975e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 56/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.8082e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 57/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.6849e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0018 - val_mean_absolute_error: 0.0333
# Epoch 58/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.8223e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0052 - val_mean_absolute_error: 0.0615
# Epoch 59/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.1355e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0034 - val_mean_absolute_error: 0.0491
# Epoch 60/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.8497e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 61/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.6354e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
# Epoch 62/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.6002e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 63/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.5919e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 64/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.5301e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 65/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.6504e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0020 - val_mean_absolute_error: 0.0365
# Epoch 66/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.7384e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 67/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.5873e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0022 - val_mean_absolute_error: 0.0381
# Epoch 68/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.6206e-04 - mean_absolute_error: 0.0093 - val_loss: 9.0094e-04 - val_mean_absolute_error: 0.0223
# Epoch 69/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.5871e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0026 - val_mean_absolute_error: 0.0419
# Epoch 70/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.3482e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 71/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.5173e-04 - mean_absolute_error: 0.0090 - val_loss: 4.2068e-04 - val_mean_absolute_error: 0.0152
# Epoch 72/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.4142e-04 - mean_absolute_error: 0.0087 - val_loss: 6.7623e-04 - val_mean_absolute_error: 0.0193
# Epoch 73/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.3261e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 74/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.3101e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0370
# Epoch 75/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.3324e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 76/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.3817e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 77/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.2662e-04 - mean_absolute_error: 0.0082 - val_loss: 6.9336e-04 - val_mean_absolute_error: 0.0202
# Epoch 78/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.2313e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0017 - val_mean_absolute_error: 0.0340
# Epoch 79/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.2025e-04 - mean_absolute_error: 0.0079 - val_loss: 8.9728e-04 - val_mean_absolute_error: 0.0241
# Epoch 80/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.2373e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 81/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.3771e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 82/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.2705e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 83/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.1509e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0027 - val_mean_absolute_error: 0.0439
# Epoch 84/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.3082e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 85/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.1734e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0020 - val_mean_absolute_error: 0.0374
# Epoch 86/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.1548e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 87/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.1736e-04 - mean_absolute_error: 0.0077 - val_loss: 7.2776e-04 - val_mean_absolute_error: 0.0216
# Epoch 88/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.1952e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0016 - val_mean_absolute_error: 0.0340
# Epoch 89/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.1080e-04 - mean_absolute_error: 0.0075 - val_loss: 7.6611e-04 - val_mean_absolute_error: 0.0215
# Epoch 90/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.0848e-04 - mean_absolute_error: 0.0072 - val_loss: 8.7405e-04 - val_mean_absolute_error: 0.0236
# Epoch 91/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.0880e-04 - mean_absolute_error: 0.0075 - val_loss: 8.4639e-04 - val_mean_absolute_error: 0.0235
# Epoch 92/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.2573e-04 - mean_absolute_error: 0.0081 - val_loss: 4.2205e-04 - val_mean_absolute_error: 0.0153
# Epoch 93/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.1375e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 94/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.0613e-04 - mean_absolute_error: 0.0073 - val_loss: 7.5473e-04 - val_mean_absolute_error: 0.0215
# Epoch 95/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.0237e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 96/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.0934e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 97/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.1420e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0017 - val_mean_absolute_error: 0.0341
# Epoch 98/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.0770e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0020 - val_mean_absolute_error: 0.0385
# Epoch 99/100
# 28/28 [==============================] - 1s 44ms/step - loss: 9.9903e-05 - mean_absolute_error: 0.0071 - val_loss: 9.4501e-04 - val_mean_absolute_error: 0.0248
# Epoch 100/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.0972e-04 - mean_absolute_error: 0.0073 - val_loss: 4.4053e-04 - val_mean_absolute_error: 0.0160

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 12ms/step
# array([[0.41283068, 0.41090024],
#        [0.410649  , 0.40834352],
#        [0.4045574 , 0.4022736 ],
#        [0.4106185 , 0.40894324],
#        [0.41422582, 0.41261756]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1436.355 , 1429.7979],
#        [1432.3104, 1425.0593],
#        [1421.0171, 1413.8098],
#        [1432.2538, 1426.1709],
#        [1438.9415, 1432.9807]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1436.354980      1429.797852
# 2020-05-28  1396.86  1416.73     1432.310425      1425.059326
# 2020-05-29  1416.94  1428.92     1421.017090      1413.809814
# 2020-06-01  1418.39  1431.82     1432.253784      1426.170898
# 2020-06-02  1430.55  1439.22     1438.941528      1432.980713

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
b=pd.DataFrame(columns=df_merge.columns,index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = pd.concat([df_merge,pd.DataFrame(columns=df_merge.columns,index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))])
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2434.672119      2464.609619
# 2021-06-10  2494.01  2521.60     2444.332764      2474.059082
# 2021-06-11  2524.92  2513.93     2457.537109      2487.330811
# 2021-06-11      NaN      NaN             NaN              NaN
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
